# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
df = pd.read_csv('fake_insta.csv')

# %%
df.head(10)
# Out:
#   has_a_profile_pic  number_of_words_in_name  num_characters_in_bio  \
# 0               yes                        1                     30
# 1               yes                        5                     64
# 2               yes                        2                     82
# 3               yes                        1                    143
# 4               yes                        1                     76
# 5               yes                        1                      0
# 6               yes                        1                    132
# 7               yes                        2                      0
# 8               yes                        2                     96
# 9               yes                        1                     78
#
#    number_of_posts  number_of_followers  number_of_follows account_type
# 0               35                  488                604         real
# 1                3                   35                  6         real
# 2              319                  328                668         real
# 3              273                14890               7369         real
# 4                6                  225                356         real
# 5                6                  362                424         real
# 6                9                  213                254         real
# 7               19                  552                521         real
# 8               17                  122                143         real
# 9                9                  834                358         real

# %%
df.shape
# Out:
# (120, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   has_a_profile_pic        120 non-null    object
#  1   number_of_words_in_name  120 non-null    int64
#  2   num_characters_in_bio    120 non-null    int64
#  3   number_of_posts          120 non-null    int64
#  4   number_of_followers      120 non-null    int64
#  5   number_of_follows        120 non-null    int64
#  6   account_type             120 non-null    object
# dtypes: int64(5), object(2)
# memory usage: 6.7+ KB

# %%
df.describe()
# Out:
#        number_of_words_in_name  num_characters_in_bio  number_of_posts  \
# count               120.000000             120.000000       120.000000
# mean                  1.550000              27.200000        82.866667
# std                   1.187116              42.588632       230.468136
# min                   0.000000               0.000000         0.000000
# 25%                   1.000000               0.000000         1.000000
# 50%                   1.000000               0.000000         8.000000
# 75%                   2.000000              45.250000        58.250000
# max                   9.000000             149.000000      1879.000000
#
#        number_of_followers  number_of_follows
# count         1.200000e+02         120.000000
# mean          4.959472e+04         779.266667
# std           3.816126e+05        1409.383558
# min           0.000000e+00           1.000000
# 25%           6.725000e+01         119.250000
# 50%           2.165000e+02         354.500000
# 75%           5.932500e+02         668.250000
# max           4.021842e+06        7453.000000

# %%
pd.crosstab(df['has_a_profile_pic'],df['account_type'],normalize = 'index')
# Out:
# account_type           fake      real
# has_a_profile_pic
# no                 1.000000  0.000000
# yes                0.340659  0.659341

# %%
has_pic_count = df['has_a_profile_pic'].value_counts()
account_type_count = df['account_type'].value_counts()

# %%
sns.barplot(data = df, x = has_pic_count.index, y = has_pic_count)
plt.title('Has a profile picture?')
plt.xlabel('Has a profile picture?')
plt.ylabel('Number of accounts')

plt.show()
